# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
train = pd.read_csv('C:\\Users\\Divyesh\\Desktop\\4661\\Project\\train.csv')
train
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0         1/1/2011 0:00       1        0           0        1   9.84  14.395
# 1         1/1/2011 1:00       1        0           0        1   9.02  13.635
# 2         1/1/2011 2:00       1        0           0        1   9.02  13.635
# 3         1/1/2011 3:00       1        0           0        1   9.84  14.395
# 4         1/1/2011 4:00       1        0           0        1   9.84  14.395
# 5         1/1/2011 5:00       1        0           0        2   9.84  12.880
# 6         1/1/2011 6:00       1        0           0        1   9.02  13.635
# 7         1/1/2011 7:00       1        0           0        1   8.20  12.880
# 8         1/1/2011 8:00       1        0           0        1   9.84  14.395
# 9         1/1/2011 9:00       1        0           0        1  13.12  17.425
# 10       1/1/2011 10:00       1        0           0        1  15.58  19.695
# ...

# %%
train.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  1/1/2011 0:00       1        0           0        1  9.84  14.395
# 1  1/1/2011 1:00       1        0           0        1  9.02  13.635
# 2  1/1/2011 2:00       1        0           0        1  9.02  13.635
# 3  1/1/2011 3:00       1        0           0        1  9.84  14.395
# 4  1/1/2011 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.tail()
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 10881  12/19/2012 19:00       4        0           1        1  15.58  19.695
# 10882  12/19/2012 20:00       4        0           1        1  14.76  17.425
# 10883  12/19/2012 21:00       4        0           1        1  13.94  15.910
# 10884  12/19/2012 22:00       4        0           1        1  13.94  17.425
# 10885  12/19/2012 23:00       4        0           1        1  13.12  16.665
#
#        humidity  windspeed  casual  registered  count
# 10881        50    26.0027       7         329    336
# 10882        57    15.0013      10         231    241
# 10883        61    15.0013       4         164    168
# 10884        61     6.0032      12         117    129
# 10885        66     8.9981       4          84     88

# %%
test = pd.read_csv('C:\\Users\\Divyesh\\Desktop\\4661\\Project\\test.csv')
test
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0       1/20/2011 0:00       1        0           1        1  10.66  11.365
# 1       1/20/2011 1:00       1        0           1        1  10.66  13.635
# 2       1/20/2011 2:00       1        0           1        1  10.66  13.635
# 3       1/20/2011 3:00       1        0           1        1  10.66  12.880
# 4       1/20/2011 4:00       1        0           1        1  10.66  12.880
# 5       1/20/2011 5:00       1        0           1        1   9.84  11.365
# 6       1/20/2011 6:00       1        0           1        1   9.02  10.605
# 7       1/20/2011 7:00       1        0           1        1   9.02  10.605
# 8       1/20/2011 8:00       1        0           1        1   9.02  10.605
# 9       1/20/2011 9:00       1        0           1        2   9.84  11.365
# 10     1/20/2011 10:00       1        0           1        1  10.66  11.365
# ...

# %%
test.head()
# Out:
#          datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  1/20/2011 0:00       1        0           1        1  10.66  11.365
# 1  1/20/2011 1:00       1        0           1        1  10.66  13.635
# 2  1/20/2011 2:00       1        0           1        1  10.66  13.635
# 3  1/20/2011 3:00       1        0           1        1  10.66  12.880
# 4  1/20/2011 4:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
test.tail()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 6488  12/31/2012 19:00       1        0           1        2  10.66  12.880
# 6489  12/31/2012 20:00       1        0           1        2  10.66  12.880
# 6490  12/31/2012 21:00       1        0           1        1  10.66  12.880
# 6491  12/31/2012 22:00       1        0           1        1  10.66  13.635
# 6492  12/31/2012 23:00       1        0           1        1  10.66  13.635
#
#       humidity  windspeed
# 6488        60    11.0014
# 6489        60    11.0014
# 6490        60    11.0014
# 6491        56     8.9981
# 6492        65     8.9981

# %%
dt = pd.to_datetime(train["datetime"])
train["hour"] = dt.map(lambda x: x.hour)
train.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  1/1/2011 0:00       1        0           0        1  9.84  14.395
# 1  1/1/2011 1:00       1        0           0        1  9.02  13.635
# 2  1/1/2011 2:00       1        0           0        1  9.02  13.635
# 3  1/1/2011 3:00       1        0           0        1  9.84  14.395
# 4  1/1/2011 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour
# 0        81        0.0       3          13     16     0
# 1        80        0.0       8          32     40     1
# 2        80        0.0       5          27     32     2
# 3        75        0.0       3          10     13     3
# 4        75        0.0       0           1      1     4

# %%
dt_test = pd.to_datetime(test["datetime"])
test["hour"] = dt_test.map(lambda x: x.hour)
test.head()
# Out:
#          datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  1/20/2011 0:00       1        0           1        1  10.66  11.365
# 1  1/20/2011 1:00       1        0           1        1  10.66  13.635
# 2  1/20/2011 2:00       1        0           1        1  10.66  13.635
# 3  1/20/2011 3:00       1        0           1        1  10.66  12.880
# 4  1/20/2011 4:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  hour
# 0        56    26.0027     0
# 1        56     0.0000     1
# 2        56     0.0000     2
# 3        56    11.0014     3
# 4        56    11.0014     4

# %%
def categorical_to_numeric(x):
    if 0 <=  x < 6:
        return 0
    elif 6 <= x < 13:
        return 1
    elif 13 <= x < 19:
        return 2
    elif 19 <= x < 24:
        return 3
    
    
train['hour'] = train['hour'].apply(categorical_to_numeric)
train.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  1/1/2011 0:00       1        0           0        1  9.84  14.395
# 1  1/1/2011 1:00       1        0           0        1  9.02  13.635
# 2  1/1/2011 2:00       1        0           0        1  9.02  13.635
# 3  1/1/2011 3:00       1        0           0        1  9.84  14.395
# 4  1/1/2011 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour
# 0        81        0.0       3          13     16     0
# 1        80        0.0       8          32     40     0
# 2        80        0.0       5          27     32     0
# 3        75        0.0       3          10     13     0
# 4        75        0.0       0           1      1     0

# %%
train.tail()
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 10881  12/19/2012 19:00       4        0           1        1  15.58  19.695
# 10882  12/19/2012 20:00       4        0           1        1  14.76  17.425
# 10883  12/19/2012 21:00       4        0           1        1  13.94  15.910
# 10884  12/19/2012 22:00       4        0           1        1  13.94  17.425
# 10885  12/19/2012 23:00       4        0           1        1  13.12  16.665
#
#        humidity  windspeed  casual  registered  count  hour
# 10881        50    26.0027       7         329    336     3
# 10882        57    15.0013      10         231    241     3
# 10883        61    15.0013       4         164    168     3
# 10884        61     6.0032      12         117    129     3
# 10885        66     8.9981       4          84     88     3

# %%
        
test['hour'] = test['hour'].apply(categorical_to_numeric)
test.head()
# Out:
#          datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  1/20/2011 0:00       1        0           1        1  10.66  11.365
# 1  1/20/2011 1:00       1        0           1        1  10.66  13.635
# 2  1/20/2011 2:00       1        0           1        1  10.66  13.635
# 3  1/20/2011 3:00       1        0           1        1  10.66  12.880
# 4  1/20/2011 4:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  hour
# 0        56    26.0027     0
# 1        56     0.0000     0
# 2        56     0.0000     0
# 3        56    11.0014     0
# 4        56    11.0014     0

# %%
test.tail()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 6488  12/31/2012 19:00       1        0           1        2  10.66  12.880
# 6489  12/31/2012 20:00       1        0           1        2  10.66  12.880
# 6490  12/31/2012 21:00       1        0           1        1  10.66  12.880
# 6491  12/31/2012 22:00       1        0           1        1  10.66  13.635
# 6492  12/31/2012 23:00       1        0           1        1  10.66  13.635
#
#       humidity  windspeed  hour
# 6488        60    11.0014     3
# 6489        60    11.0014     3
# 6490        60    11.0014     3
# 6491        56     8.9981     3
# 6492        65     8.9981     3

# %%
train[0: :10]
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0         1/1/2011 0:00       1        0           0        1   9.84  14.395
# 10       1/1/2011 10:00       1        0           0        1  15.58  19.695
# 20       1/1/2011 20:00       1        0           0        2  16.40  20.455
# 30        1/2/2011 7:00       1        0           0        2  16.40  20.455
# 40       1/2/2011 17:00       1        0           0        1  13.94  16.665
# 50        1/3/2011 5:00       1        0           1        1   6.56   6.820
# 60       1/3/2011 15:00       1        0           1        1  10.66  12.120
# 70        1/4/2011 1:00       1        0           1        1   6.56   9.090
# 80       1/4/2011 12:00       1        0           1        1   9.02  11.365
# 90       1/4/2011 22:00       1        0           1        1   9.02  12.880
# 100       1/5/2011 9:00       1        0           1        1   9.02   9.850
# ...

# %%
test[0: :10]
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0       1/20/2011 0:00       1        0           1        1  10.66  11.365
# 10     1/20/2011 10:00       1        0           1        1  10.66  11.365
# 20     1/20/2011 20:00       1        0           1        2  10.66  12.120
# 30      1/21/2011 6:00       1        0           1        1   9.02  10.605
# 40     1/21/2011 16:00       1        0           1        1   6.56   6.820
# 50      1/22/2011 2:00       1        0           0        2   1.64   1.515
# 60     1/22/2011 13:00       1        0           0        1   3.28   8.335
# 70     1/22/2011 23:00       1        0           0        1   1.64   3.790
# 80     1/23/2011 10:00       1        0           0        1   5.74   5.305
# 90     1/23/2011 20:00       1        0           0        1   4.10   5.305
# 100     1/24/2011 7:00       1        0           1        1   0.82   6.060
# ...

# %%
figure,axes = plt.subplots(figsize = (10, 5))
hours = train.groupby(["hour"]).agg("mean")["count"]  
hours.plot(kind="line", ax=axes) 
plt.title('Hours VS Counts')
axes.set_xlabel('Time in Hours')
axes.set_ylabel('Average of the Bike Demand')
plt.show()

# %%
a = train.groupby('temp')[['count']].mean()
a.plot()
plt.show()

# %%
a = train.groupby('atemp')[['count']].mean()
a.plot()
plt.show()

# %%
a = train.groupby('holiday')[['count']].mean()
a.plot()
plt.show()

# %%
# Creating the Feature Matrix for Heart dataset:

# create a python list of feature names that would like to pick from the dataset:

feature_cols = ['season','holiday','workingday','weather','temp' , 'atemp' ,'humidity','windspeed', 'hour']

# use the above list to select the features from the original DataFrame
X =train[feature_cols]

# this is the original categorical labels (the latest revision of sklearn accepts non-numerical labels)
y =train['count']


# print the first 5 rows
print(X.head())

# print the first 5 rows
print(y.head())
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    hour
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
time = train.set_index('count')

# %%
#feature_cols = [ 'season','holiday','workingday','weather','temp' , 'atemp' ,'humidity','windspeed', 'hour']
for f in feature_cols:
    plt.figure()
    plt.title(f)
    time[f].plot(kind='hist')
    plt.show()

# %%
max(y)
# Out:
# 977

# %%
y.mean()
# Out:
# 191.57413191254824

# %%
# Creating the Feature Matrix for Heart dataset:

# create a python list of feature names that would like to pick from the dataset:

feature_cols_test = ['season','holiday','workingday','weather','temp' , 'atemp' ,'humidity','windspeed', 'hour']

# use the above list to select the features from the original DataFrame
X_testData =test[feature_cols]


# print the first 5 rows
print(X_testData.head())
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    hour
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
# import preprocessing to normalize data
from sklearn.preprocessing import scale 
# scaling the feature matrix using preprocessing.scale() function

X_minmax=scale(X)

X=pd.DataFrame(X_minmax,columns=X.columns)

print(X.head())
# Out:
#      season  holiday  workingday   weather      temp     atemp  humidity  \
# 0 -1.349864 -0.17149   -1.460672 -0.660178 -1.333661 -1.092737  0.993213
# 1 -1.349864 -0.17149   -1.460672 -0.660178 -1.438907 -1.182421  0.941249
# 2 -1.349864 -0.17149   -1.460672 -0.660178 -1.438907 -1.182421  0.941249
# 3 -1.349864 -0.17149   -1.460672 -0.660178 -1.333661 -1.092737  0.681430
# 4 -1.349864 -0.17149   -1.460672 -0.660178 -1.333661 -1.092737  0.681430
#
#    windspeed      hour
# 0  -1.567754 -1.324026
# 1  -1.567754 -1.324026
# 2  -1.567754 -1.324026
# 3  -1.567754 -1.324026
# 4  -1.567754 -1.324026

# %%
X_minmax_test=scale(X_testData)

X_testData=pd.DataFrame(X_minmax_test,columns=X_testData.columns)

print(X_testData.head())
# Out:
#      season  holiday  workingday   weather      temp     atemp  humidity  \
# 0 -1.368527 -0.17315    0.676844 -0.673687 -1.235966 -1.440193 -0.421172
# 1 -1.368527 -0.17315    0.676844 -0.673687 -1.235966 -1.181711 -0.421172
# 2 -1.368527 -0.17315    0.676844 -0.673687 -1.235966 -1.181711 -0.421172
# 3 -1.368527 -0.17315    0.676844 -0.673687 -1.235966 -1.267682 -0.421172
# 4 -1.368527 -0.17315    0.676844 -0.673687 -1.235966 -1.267682 -0.421172
#
#    windspeed      hour
# 0   1.620888 -1.327682
# 1  -1.531139 -1.327682
# 2  -1.531139 -1.327682
# 3  -0.197558 -1.327682
# 4  -0.197558 -1.327682

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
# print the size of the traning set:

print(X_train.shape)
print(y_train.shape)

# print the size of the testing set:

print(X_test.shape)
print(y_test.shape)
# Out:
# (8708, 9)
# (8708,)
# (2178, 9)
# (2178,)

# %%
print(X_train.head())
print(X_test.head())
print(y_train.head())
print(y_test.head())
# Out:
#         season  holiday  workingday   weather      temp     atemp  humidity  \
# 5871 -1.349864 -0.17149    0.684616 -0.660178 -1.228414 -1.539976 -0.513738
# 4966  1.338012 -0.17149    0.684616 -0.660178 -1.123168 -1.271515 -0.513738
# 7573 -0.453905 -0.17149    0.684616  0.917583  0.455530  0.427168  0.837322
# 3557  0.442053 -0.17149    0.684616 -0.660178  0.876516  0.873818  0.369647
# 6776 -1.349864 -0.17149    0.684616 -0.660178  0.771270  0.873818 -0.253919
#
#       windspeed      hour
# 5871   2.107161  1.466014
# 4966   1.127293 -1.324026
# 7573  -0.832442  1.466014
# 3557   0.759638 -1.324026
# 6776   0.269704  0.536001
#         season   holiday  workingday   weather      temp     atemp  humidity  \
# 6198 -1.349864 -0.171490    0.684616  0.917583 -1.017921 -1.092737 -0.513738
# 8947  0.442053 -0.171490    0.684616 -0.660178  0.771270  0.605946  1.097141
# 182  -1.349864 -0.171490   -1.460672 -0.660178 -1.965140 -2.165403 -1.189268
# ...

# %%
# The following line will import LinearRegression "Class"

from sklearn.linear_model import LinearRegression
# In the following line, "my_linreg" is instantiated as an "object" of LinearRegression "class". 

my_linreg = LinearRegression()

# fitting the model to the training data:
my_linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# "my_RandomForest" is instantiated as an "object" of RandomForestClassifier "class". 

my_RandomForest =RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=2)

# %%
my_RandomForest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=19, n_jobs=1, oob_score=False, random_state=2,
#             verbose=0, warm_start=False)

# %%
# printing Theta0 using attribute "intercept_":
print(my_linreg.intercept_)

# printing [Theta1, Theta2, Theta3] using attribute "coef_":
print(my_linreg.coef_)
# Out:
# 192.099213021
# [ 24.90077471  -0.8895506   -0.36062901  -1.79752528  13.42812518
#   41.83443116 -44.88912424   3.31580288  49.70558986]

# %%
# make predictions on the testing set for train data
y_prediction = my_linreg.predict(X_test)

print(y_prediction)
# Out:
# [ 101.73096012  122.4892021   174.17910433 ...,  214.02880076  237.34356929
#    33.2184606 ]

# %%
# Testing on the testing set:

y_predict_rf= my_RandomForest.predict(X_test)

print(y_predict_rf)
# Out:
# [ 53   7  34 ..., 454 125   7]

# %%
# make predictions on the testing set for test data
y_prediction_test = my_linreg.predict(X_testData)

print(y_prediction_test)
# Out:
# [  40.58377501   40.94569369   40.94569369 ...,  171.28463504  183.38331362
#   162.44177811]

# %%
# make predictions on the testing set for test data
y_prediction_test =my_RandomForest.predict(X_testData)

print(y_prediction_test)
# Out:
# [ 3 16 16 ..., 71 97 77]

# %%
from sklearn import metrics

# Calculating "Mean Square Error" (MSE):
mse = metrics.mean_squared_error(y_test, y_prediction)
mse_rf = metrics.mean_squared_error(y_test, y_predict_rf)

# Using numpy sqrt function to take the square root and calculate "Root Mean Square Error" (RMSE)
rmse = np.sqrt(mse)
rmse_rf = np.sqrt(mse_rf)

print ("Linear Regression: ",rmse)
print ("Random Forest: ", rmse_rf)
# Out:
# Linear Regression:  146.854010961
# Random Forest:  153.398471013

# %%
# importing the method:
from sklearn.cross_validation import cross_val_score
# Out:
# C:\Users\Divyesh\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
my_linreg = LinearRegression()

mse_list = cross_val_score(my_linreg, X, y, cv=10, scoring='neg_mean_squared_error')

print(mse_list)
# Out:
# [-11108.74713222 -12440.78811023 -21181.00255258 -16484.02712319
#  -14790.52737928 -16199.67019541 -35770.35872989 -35444.10714925
#  -43928.55863166 -33869.00358579]

# %%
# in order to calculate root mean square error (rmse), we have to make them positive!
mse_list_positive = -mse_list

# using numpy sqrt function to calculate rmse:
rmse_list = np.sqrt(mse_list_positive)
print(rmse_list)
# Out:
# [ 105.39804141  111.53828092  145.53694566  128.39013639  121.61631214
#   127.27792501  189.13053357  188.26605416  209.59140877  184.03533244]

# %%
# calculate the average RMSE as final result of cross validation:
print(rmse_list.mean())
# Out:
# 151.078097048

# %%
#Plot learning curve
from sklearn.model_selection import learning_curve
train_sizes_abs, train_scores, test_scores = learning_curve(my_linreg ,X, y, n_jobs=-1,cv=10, verbose=0, scoring='neg_mean_squared_error',train_sizes=np.array([ 0.1, 0.33, 0.55, 0.78, 1. ]))
plt.plot(train_sizes_abs, train_scores)
plt.plot(train_sizes_abs, test_scores)
plt.show()

# %%
#Mean learning curves for different cross validation folds
train_score_mean = np.mean(train_scores,axis=1)
test_score_mean = np.mean(test_scores,axis=1)
plt.plot(train_sizes_abs,train_score_mean)
plt.plot(train_sizes_abs, test_score_mean)
plt.show()

# %%
fianl_submit = test

# %%
fianl_submit['count'] = np.round(y_prediction_test)

# %%
fianl_submit=fianl_submit.drop(['season', 'holiday', 'workingday','weather', 'temp', 'atemp', 'humidity', 'windspeed', 'hour'], axis=1)

# %%
fianl_submit.head(10)
# Out:
#          datetime  count
# 0  1/20/2011 0:00      3
# 1  1/20/2011 1:00     16
# 2  1/20/2011 2:00     16
# 3  1/20/2011 3:00      2
# 4  1/20/2011 4:00      2
# 5  1/20/2011 5:00     15
# 6  1/20/2011 6:00    230
# 7  1/20/2011 7:00     97
# 8  1/20/2011 8:00     68
# 9  1/20/2011 9:00     86

# %%
fianl_submit.tail(10)
# Out:
#               datetime  count
# 6483  12/31/2012 14:00     91
# 6484  12/31/2012 15:00     62
# 6485  12/31/2012 16:00     82
# 6486  12/31/2012 17:00     67
# 6487  12/31/2012 18:00     82
# 6488  12/31/2012 19:00     71
# 6489  12/31/2012 20:00     71
# 6490  12/31/2012 21:00     71
# 6491  12/31/2012 22:00     97
# 6492  12/31/2012 23:00     77

# %%
a = test.groupby('datetime')[['count']].mean()
a.plot()
plt.show()
